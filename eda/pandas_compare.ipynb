# %%
import pandas as pd

# %%
df_query1_before = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q1-Before')
df_query2_before = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q2-Before')
df_query3_before = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q3-Before')
df_query1_after = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q1-After')
df_query2_after = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q2-After')
df_query3_after = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q3-After')

# %%
import pandas as pd

df_query2_before = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q1-Before')
df_query2_after = pd.read_excel('../data/CostCompareCompare.xlsx', sheet_name = 'Q1-After')

df_query2_before.compare(df_query2_after)
# Out:
#      NewRankA         NewRankB         NewRankC        NewRankD
#          self   other     self   other     self  other     self   other
# 1115      1.0  1.0417     1.02  1.0408      1.1  1.134     1.15  1.2105
# 1487      1.0  1.0417     1.02  1.0408      1.1  1.134     1.15  1.2105

# %%
df_query1_before.sort_values(by = ['PriceTerritory', 'PriceClass', 'PriceLineID', 'SellGroup'], inplace = True)
df_query1_after.sort_values(by = ['PriceTerritory', 'PriceClass', 'PriceLineID', 'SellGroup'], inplace = True)

df_query1_before.reset_index(inplace = True, drop=True)
df_query1_after.reset_index(inplace = True, drop=True)

df_query1_before.compare(df_query1_after)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_query2_before.sort_values(by = ['PriceTerritory', 'PriceClass', 'PriceLineID', 'SellGroup'], inplace = True)
df_query2_after.sort_values(by = ['PriceTerritory', 'PriceClass', 'PriceLineID', 'SellGroup'], inplace = True)

df_query2_before.reset_index(inplace = True, drop=True)
df_query2_after.reset_index(inplace = True, drop=True)

df_query2_before.compare(df_query2_after)
# Out:
#      NewRankA         NewRankB         NewRankC        NewRankD
#          self   other     self   other     self  other     self   other
# 1115      1.0  1.0417     1.02  1.0408      1.1  1.134     1.15  1.2105
# 1487      1.0  1.0417     1.02  1.0408      1.1  1.134     1.15  1.2105

# %%
df_query2_before.iloc[[1, 1115, 1487]]
# Out:
#      PriceTerritory PriceClass PriceLineID  SellGroup    RankType  CostBasis  \
# 1          PTR03MON     CASHE1     CROUSEH    CRS-002     NO RANK  COMM-COST
# 1115       PTR03MON     CASHN1     CROUSEH  CRS-WPCVR  ADDITIONAL   REP-COST
# 1487       PTR03MON     CASHNE     CROUSEH  CRS-WPCVR  ADDITIONAL   REP-COST
#
#      BaseForm  RankA  RankB  RankC  ...  NewRankA NewRankB  NewRankC  \
# 1     *1.6946      0   0.00    0.0  ...       NaN      NaN       NaN
# 1115  *1.8313      1   1.02    1.1  ...       1.0     1.02       1.1
# 1487  *1.7580      1   1.02    1.1  ...       1.0     1.02       1.1
#
#       NewRankD  Sales12Month  GM12Month  Qty12Month  Lines12Month  \
# 1          NaN           0.0        0.0           0             0
# 1115      1.15           0.0        0.0           0             0
# 1487      1.15           0.0        0.0           0             0
#
#       EffectiveDate  Code
# 1        2022-06-15    CI
# 1115     2022-06-15    CI
# 1487     2022-06-15    CI
# ...

# %%
df_query2_after.iloc[[1, 1115, 1487]]
# Out:
#      PriceTerritory PriceClass PriceLineID  SellGroup    RankType  CostBasis  \
# 1          PTR03MON     CASHE1     CROUSEH    CRS-002     NO RANK  COMM-COST
# 1115       PTR03MON     CASHN1     CROUSEH  CRS-WPCVR  ADDITIONAL   REP-COST
# 1487       PTR03MON     CASHNE     CROUSEH  CRS-WPCVR  ADDITIONAL   REP-COST
#
#      BaseForm  RankA  RankB  RankC  ...  NewRankA NewRankB  NewRankC  \
# 1     *1.6946      0   0.00    0.0  ...       NaN      NaN       NaN
# 1115  *1.8313      1   1.02    1.1  ...    1.0417   1.0408     1.134
# 1487  *1.7580      1   1.02    1.1  ...    1.0417   1.0408     1.134
#
#       NewRankD  Sales12Month  GM12Month  Qty12Month  Lines12Month  \
# 1          NaN           0.0        0.0           0             0
# 1115    1.2105           0.0        0.0           0             0
# 1487    1.2105           0.0        0.0           0             0
#
#       EffectiveDate  Code
# 1        2022-06-15    CI
# 1115     2022-06-15    CI
# 1487     2022-06-15    CI
# ...

# %%
df_query3_before.sort_values(by = ['PriceTerritory', 'PriceClass', 'PriceLineID', 'SellGroup'], inplace = True)
df_query3_after.sort_values(by = ['PriceTerritory', 'PriceClass', 'PriceLineID', 'SellGroup'], inplace = True)

df_query3_before.reset_index(inplace = True, drop=True)
df_query3_after.reset_index(inplace = True, drop=True)

df_query3_before.compare(df_query3_after)
# Out:
#     NewRankA         NewRankB         NewRankC         NewRankD          \
#         self   other     self   other     self   other     self   other
# 0        1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 1        1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 2        1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 3        1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 4        1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# ..       ...     ...      ...     ...      ...     ...      ...     ...
# 403      1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 404      1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 405      1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 406      1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
# 407      1.0  1.0417      1.0  1.0204   1.1787  1.2152   1.3781  1.4506
#
#             Lines12Month
# ...
